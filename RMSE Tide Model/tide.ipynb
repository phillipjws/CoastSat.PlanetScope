# %%
#%%

import pyfes
import os
import pytz
import datetime
import csv
import numpy as np
import matplotlib.pyplot as plt
from coastsat_ps import SDS_slope
from sklearn.metrics import root_mean_squared_error

# %%
#%% Load FES2022 configuration

print('Loading fes2022')
config_filepath = os.pardir
config = os.path.join(config_filepath, 'fes2022.yaml')
handlers = pyfes.load_config(config)
ocean_tide = handlers['tide']
load_tide = handlers['radial']
# Out:
# Loading fes2022

# %%
#%%

centroid = [-125.13745727502629, 48.83921278599814]
centroid[0] = centroid[0] + 360
date_range = [pytz.utc.localize(datetime.datetime(2014, 1, 1)), pytz.utc.localize(datetime.datetime(2015, 1, 1))]
timestep = 60 * 60  # 1 hour in seconds

dates_ts, tides_ts = SDS_slope.compute_tide(centroid, date_range, timestep, ocean_tide, load_tide)

# Adjust the predicted tide with the given offset
offset = 1.8
predicted_tides = np.array(tides_ts) + offset

dates_csv = []
observed_tides = []
with open('8545-01-JAN-2014_slev.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip header
    for row in reader:
        if len(row) >= 2:
            timestamp = datetime.datetime.strptime(row[0], '%Y-%m-%d %H:%M')
            dates_csv.append(pytz.utc.localize(timestamp))
            observed_tides.append(float(row[1]))

aligned_observed = []
aligned_predicted = []
aligned_dates = []

for date, pred_tide in zip(dates_ts, predicted_tides):
    if date in dates_csv:
        index = dates_csv.index(date)
        aligned_observed.append(observed_tides[index])
        aligned_predicted.append(pred_tide)
        aligned_dates.append(date)

# Calculate RMSE
rmse = root_mean_squared_error(aligned_observed, aligned_predicted)
print(f"RMSE between observed and predicted water levels: {rmse:.3f} metres")

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(aligned_dates, aligned_observed, label="Observed Water Level", color="blue", marker="o", linestyle="--")
plt.plot(aligned_dates, aligned_predicted, label="Predicted Water Level", color="orange", marker="x", linestyle="-")
plt.xlabel("Date and Time (UTC)")
plt.ylabel("Water Level (metres)")
plt.title("Observed vs Predicted Water Levels Bamfield With Offset 1.8m")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# Flags (Ocean): [3]
# Flags (Load): [4]
# RMSE between observed and predicted water levels: 0.521 metres

# %%
#%%

centroid = [-123.476604805765675, 48.659207281106546]
centroid[0] = centroid[0] + 360
date_range = [pytz.utc.localize(datetime.datetime(2014, 1, 1)), pytz.utc.localize(datetime.datetime(2024, 1, 1))]
timestep = 60 * 60  # 1 hour in seconds

dates_ts, tides_ts = SDS_slope.compute_tide(centroid, date_range, timestep, ocean_tide, load_tide)

# Adjust the predicted tide with the given offset
offset = 2.1
predicted_tides = np.array(tides_ts) + offset

dates_csv = []
observed_tides = []
with open('7277-01-JAN-2014_slev.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip header
    for row in reader:
        if len(row) >= 2:
            timestamp = datetime.datetime.strptime(row[0], '%Y-%m-%d %H:%M')
            dates_csv.append(pytz.utc.localize(timestamp))
            observed_tides.append(float(row[1]))

aligned_observed = []
aligned_predicted = []
aligned_dates = []

for date, pred_tide in zip(dates_ts, predicted_tides):
    if date in dates_csv:
        index = dates_csv.index(date)
        aligned_observed.append(observed_tides[index])
        aligned_predicted.append(pred_tide)
        aligned_dates.append(date)

# Calculate RMSE
rmse = root_mean_squared_error(aligned_observed, aligned_predicted)
print(f"RMSE between observed and predicted water levels: {rmse:.3f} metres")

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(aligned_dates, aligned_observed, label="Observed Water Level", color="blue", marker="o", linestyle="--")
plt.plot(aligned_dates, aligned_predicted, label="Predicted Water Level", color="orange", marker="x", linestyle="-")
plt.xlabel("Date and Time (UTC)")
plt.ylabel("Water Level (metres)")
plt.title("Observed vs Predicted Water Levels Patricia With Offset 2.1m")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# Flags (Ocean): [2]
# Flags (Load): [4]
# RMSE between observed and predicted water levels: 1.515 metres

# %%
#%%

centroid = [-130.54719267335727,
          54.25519913486852]
centroid[0] = centroid[0] + 360
date_range = [pytz.utc.localize(datetime.datetime(2014, 1, 1)), pytz.utc.localize(datetime.datetime(2014, 2, 1))]
timestep = 60 * 60  # 1 hour in seconds

dates_ts, tides_ts = SDS_slope.compute_tide(centroid, date_range, timestep, ocean_tide, load_tide)

# Adjust the predicted tide with the given offset
offset = 3.7
predicted_tides = np.array(tides_ts) + offset

dates_csv = []
observed_tides = []
with open('9354-01-JAN-2014_slev.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip header
    for row in reader:
        if len(row) >= 2:
            timestamp = datetime.datetime.strptime(row[0], '%Y-%m-%d %H:%M')
            dates_csv.append(pytz.utc.localize(timestamp))
            observed_tides.append(float(row[1]))

aligned_observed = []
aligned_predicted = []
aligned_dates = []

for date, pred_tide in zip(dates_ts, predicted_tides):
    if date in dates_csv:
        index = dates_csv.index(date)
        aligned_observed.append(observed_tides[index])
        aligned_predicted.append(pred_tide)
        aligned_dates.append(date)

# Calculate RMSE
rmse = root_mean_squared_error(aligned_observed, aligned_predicted)
print(f"RMSE between observed and predicted water levels: {rmse:.3f} metres")

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(aligned_dates, aligned_observed, label="Observed Water Level", color="blue", marker="o", linestyle="--")
plt.plot(aligned_dates, aligned_predicted, label="Predicted Water Level", color="orange", marker="x", linestyle="-")
plt.xlabel("Date and Time (UTC)")
plt.ylabel("Water Level (metres)")
plt.title("Observed vs Predicted Water Levels Prince Rupert With Offset 3.7m")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# Flags (Ocean): [4]
# Flags (Load): [4]
# RMSE between observed and predicted water levels: 0.242 metres

# %%
#%%

centroid = [-130.54719267335727,
          54.25519913486852]
centroid[0] = centroid[0] + 360
date_range = [pytz.utc.localize(datetime.datetime(2014, 1, 1)), pytz.utc.localize(datetime.datetime(2024, 1, 1))]
timestep = 60 * 60  # 1 hour in seconds

dates_ts, tides_ts = SDS_slope.compute_tide(centroid, date_range, timestep, ocean_tide, load_tide)

# Adjust the predicted tide with the given offset
offset = 3.7
predicted_tides = np.array(tides_ts) + offset

dates_csv = []
observed_tides = []
with open('9354-01-JAN-2014_slev.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip header
    for row in reader:
        if len(row) >= 2:
            timestamp = datetime.datetime.strptime(row[0], '%Y-%m-%d %H:%M')
            dates_csv.append(pytz.utc.localize(timestamp))
            observed_tides.append(float(row[1]))

aligned_observed = []
aligned_predicted = []
aligned_dates = []

for date, pred_tide in zip(dates_ts, predicted_tides):
    if date in dates_csv:
        index = dates_csv.index(date)
        aligned_observed.append(observed_tides[index])
        aligned_predicted.append(pred_tide)
        aligned_dates.append(date)

# Calculate RMSE
rmse = root_mean_squared_error(aligned_observed, aligned_predicted)
print(f"RMSE between observed and predicted water levels: {rmse:.3f} metres")

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(aligned_dates, aligned_observed, label="Observed Water Level", color="blue", marker="o", linestyle="--")
plt.plot(aligned_dates, aligned_predicted, label="Predicted Water Level", color="orange", marker="x", linestyle="-")
plt.xlabel("Date and Time (UTC)")
plt.ylabel("Water Level (metres)")
plt.title("Observed vs Predicted Water Levels Prince Rupert With Offset 3.7m")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# Flags (Ocean): [4]
# Flags (Load): [4]
# RMSE between observed and predicted water levels: 0.278 metres

# %%
#%%

centroid = [-123.37385780607738,
          48.4246577588888]
centroid[0] = centroid[0] + 360
date_range = [pytz.utc.localize(datetime.datetime(2014, 1, 1)), pytz.utc.localize(datetime.datetime(2024, 1, 1))]
timestep = 60 * 60  # 1 hour in seconds

dates_ts, tides_ts = SDS_slope.compute_tide(centroid, date_range, timestep, ocean_tide, load_tide)

# Adjust the predicted tide with the given offset
offset = 1.7
predicted_tides = np.array(tides_ts) + offset

dates_csv = []
observed_tides = []
with open('7120-01-JAN-2014_slev.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip header
    for row in reader:
        if len(row) >= 2:
            timestamp = datetime.datetime.strptime(row[0], '%Y-%m-%d %H:%M')
            dates_csv.append(pytz.utc.localize(timestamp))
            observed_tides.append(float(row[1]))

aligned_observed = []
aligned_predicted = []
aligned_dates = []

for date, pred_tide in zip(dates_ts, predicted_tides):
    if date in dates_csv:
        index = dates_csv.index(date)
        aligned_observed.append(observed_tides[index])
        aligned_predicted.append(pred_tide)
        aligned_dates.append(date)

# Calculate RMSE
rmse = root_mean_squared_error(aligned_observed, aligned_predicted)
print(f"RMSE between observed and predicted water levels: {rmse:.3f} metres")

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(aligned_dates, aligned_observed, label="Observed Water Level", color="blue", marker="o", linestyle="--")
plt.plot(aligned_dates, aligned_predicted, label="Predicted Water Level", color="orange", marker="x", linestyle="-")
plt.xlabel("Date and Time (UTC)")
plt.ylabel("Water Level (metres)")
plt.title("Observed vs Predicted Water Levels Victoria Harbour With Offset 1.7m")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# Flags (Ocean): [2]
# Flags (Load): [4]
# RMSE between observed and predicted water levels: 0.281 metres

# %%
#%%

centroid = [-123.37385780607738,
          48.4246577588888]
centroid[0] = centroid[0] + 360
date_range = [pytz.utc.localize(datetime.datetime(2014, 1, 1)), pytz.utc.localize(datetime.datetime(2014, 1, 14))]
timestep = 60 * 60  # 1 hour in seconds

dates_ts, tides_ts = SDS_slope.compute_tide(centroid, date_range, timestep, ocean_tide, load_tide)

# Adjust the predicted tide with the given offset
offset = 1.7
predicted_tides = np.array(tides_ts) + offset

dates_csv = []
observed_tides = []
with open('7120-01-JAN-2014_slev.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip header
    for row in reader:
        if len(row) >= 2:
            timestamp = datetime.datetime.strptime(row[0], '%Y-%m-%d %H:%M')
            dates_csv.append(pytz.utc.localize(timestamp))
            observed_tides.append(float(row[1]))

aligned_observed = []
aligned_predicted = []
aligned_dates = []

for date, pred_tide in zip(dates_ts, predicted_tides):
    if date in dates_csv:
        index = dates_csv.index(date)
        aligned_observed.append(observed_tides[index])
        aligned_predicted.append(pred_tide)
        aligned_dates.append(date)

# Calculate RMSE
rmse = root_mean_squared_error(aligned_observed, aligned_predicted)
print(f"RMSE between observed and predicted water levels: {rmse:.3f} metres")

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(aligned_dates, aligned_observed, label="Observed Water Level", color="blue", marker="o", linestyle="--")
plt.plot(aligned_dates, aligned_predicted, label="Predicted Water Level", color="orange", marker="x", linestyle="-")
plt.xlabel("Date and Time (UTC)")
plt.ylabel("Water Level (metres)")
plt.title("Observed vs Predicted Water Levels Victoria Harbour With Offset 1.7m")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# Flags (Ocean): [2]
# Flags (Load): [4]
# RMSE between observed and predicted water levels: 0.291 metres

# %%
#%%

centroid = [-123.48513767116432,
          48.6554860655248]
centroid[0] = centroid[0] + 360
date_range = [pytz.utc.localize(datetime.datetime(2014, 1, 1)), pytz.utc.localize(datetime.datetime(2014, 1, 14))]
timestep = 60 * 60  # 1 hour in seconds

dates_ts, tides_ts = SDS_slope.compute_tide(centroid, date_range, timestep, ocean_tide, load_tide)

# Adjust the predicted tide with the given offset
offset = 2.1
predicted_tides = np.array(tides_ts) + offset

dates_csv = []
observed_tides = []
with open('7277-01-JAN-2014_slev.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip header
    for row in reader:
        if len(row) >= 2:
            timestamp = datetime.datetime.strptime(row[0], '%Y-%m-%d %H:%M')
            dates_csv.append(pytz.utc.localize(timestamp))
            observed_tides.append(float(row[1]))

aligned_observed = []
aligned_predicted = []
aligned_dates = []

for date, pred_tide in zip(dates_ts, predicted_tides):
    if date in dates_csv:
        index = dates_csv.index(date)
        aligned_observed.append(observed_tides[index])
        aligned_predicted.append(pred_tide)
        aligned_dates.append(date)

# Calculate RMSE
rmse = root_mean_squared_error(aligned_observed, aligned_predicted)
print(f"RMSE between observed and predicted water levels: {rmse:.3f} metres")

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(aligned_dates, aligned_observed, label="Observed Water Level", color="blue", marker="o", linestyle="--")
plt.plot(aligned_dates, aligned_predicted, label="Predicted Water Level", color="orange", marker="x", linestyle="-")
plt.xlabel("Date and Time (UTC)")
plt.ylabel("Water Level (metres)")
plt.title("Observed vs Predicted Water Levels in Patricia Bay With Offset 2.1m")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# Flags (Ocean): [2]
# Flags (Load): [4]
# RMSE between observed and predicted water levels: 1.569 metres

# %%
#%%

centroid = [-123.47630208585312,
          48.65591895192125]
centroid[0] = centroid[0] + 360
date_range = [pytz.utc.localize(datetime.datetime(2014, 1, 1)), pytz.utc.localize(datetime.datetime(2014, 1, 14))]
timestep = 60 * 60  # 1 hour in seconds

dates_ts, tides_ts = SDS_slope.compute_tide(centroid, date_range, timestep, ocean_tide, load_tide)

# Adjust the predicted tide with the given offset
offset = 2.1
predicted_tides = np.array(tides_ts) + offset

dates_csv = []
observed_tides = []
with open('7277-01-JAN-2014_slev.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip header
    for row in reader:
        if len(row) >= 2:
            timestamp = datetime.datetime.strptime(row[0], '%Y-%m-%d %H:%M')
            dates_csv.append(pytz.utc.localize(timestamp))
            observed_tides.append(float(row[1]))

aligned_observed = []
aligned_predicted = []
aligned_dates = []

for date, pred_tide in zip(dates_ts, predicted_tides):
    if date in dates_csv:
        index = dates_csv.index(date)
        aligned_observed.append(observed_tides[index])
        aligned_predicted.append(pred_tide)
        aligned_dates.append(date)

# Calculate RMSE
rmse = root_mean_squared_error(aligned_observed, aligned_predicted)
print(f"RMSE between observed and predicted water levels: {rmse:.3f} metres")

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(aligned_dates, aligned_observed, label="Observed Water Level", color="blue", marker="o", linestyle="--")
plt.plot(aligned_dates, aligned_predicted, label="Predicted Water Level", color="orange", marker="x", linestyle="-")
plt.xlabel("Date and Time (UTC)")
plt.ylabel("Water Level (metres)")
plt.title("Observed vs Predicted Water Levels in Patricia Bay With Offset 2.1m")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# Flags (Ocean): [2]
# Flags (Load): [4]
# RMSE between observed and predicted water levels: 1.569 metres

# %%
#%%

centroid = [-123.47630208585312,
          48.65591895192125]
centroid[0] = centroid[0] + 360
date_range = [pytz.utc.localize(datetime.datetime(2014, 1, 1)), pytz.utc.localize(datetime.datetime(2019, 1, 1))]
timestep = 60 * 60  # 1 hour in seconds

dates_ts, tides_ts = SDS_slope.compute_tide(centroid, date_range, timestep, ocean_tide, load_tide)

# Adjust the predicted tide with the given offset
offset = 2.1
predicted_tides = np.array(tides_ts) + offset

dates_csv = []
observed_tides = []
with open('7277-01-JAN-2014_slev.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip header
    for row in reader:
        if len(row) >= 2:
            timestamp = datetime.datetime.strptime(row[0], '%Y-%m-%d %H:%M')
            dates_csv.append(pytz.utc.localize(timestamp))
            observed_tides.append(float(row[1]))

aligned_observed = []
aligned_predicted = []
aligned_dates = []

for date, pred_tide in zip(dates_ts, predicted_tides):
    if date in dates_csv:
        index = dates_csv.index(date)
        aligned_observed.append(observed_tides[index])
        aligned_predicted.append(pred_tide)
        aligned_dates.append(date)

# Calculate RMSE
rmse = root_mean_squared_error(aligned_observed, aligned_predicted)
print(f"RMSE between observed and predicted water levels: {rmse:.3f} metres")

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(aligned_dates, aligned_observed, label="Observed Water Level", color="blue", marker="o", linestyle="--")
plt.plot(aligned_dates, aligned_predicted, label="Predicted Water Level", color="orange", marker="x", linestyle="-")
plt.xlabel("Date and Time (UTC)")
plt.ylabel("Water Level (metres)")
plt.title("Observed vs Predicted Water Levels in Patricia Bay With Offset 2.1m")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# Flags (Ocean): [2]
# Flags (Load): [4]
# RMSE between observed and predicted water levels: 1.418 metres

# %%
#%%

centroid = [-132.07355559131042,
          53.24599474637989]
centroid[0] = centroid[0] + 360
date_range = [pytz.utc.localize(datetime.datetime(2014, 1, 1)), pytz.utc.localize(datetime.datetime(2019, 1, 1))]
timestep = 60 * 60  # 1 hour in seconds

dates_ts, tides_ts = SDS_slope.compute_tide(centroid, date_range, timestep, ocean_tide, load_tide)

# Adjust the predicted tide with the given offset
offset = 3.9
predicted_tides = np.array(tides_ts) + offset

dates_csv = []
observed_tides = []
with open('9850-01-JAN-2014_slev.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip header
    for row in reader:
        if len(row) >= 2:
            timestamp = datetime.datetime.strptime(row[0], '%Y-%m-%d %H:%M')
            dates_csv.append(pytz.utc.localize(timestamp))
            observed_tides.append(float(row[1]))

aligned_observed = []
aligned_predicted = []
aligned_dates = []

for date, pred_tide in zip(dates_ts, predicted_tides):
    if date in dates_csv:
        index = dates_csv.index(date)
        aligned_observed.append(observed_tides[index])
        aligned_predicted.append(pred_tide)
        aligned_dates.append(date)

# Calculate RMSE
rmse = root_mean_squared_error(aligned_observed, aligned_predicted)
print(f"RMSE between observed and predicted water levels: {rmse:.3f} metres")

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(aligned_dates, aligned_observed, label="Observed Water Level", color="blue", marker="o", linestyle="--")
plt.plot(aligned_dates, aligned_predicted, label="Predicted Water Level", color="orange", marker="x", linestyle="-")
plt.xlabel("Date and Time (UTC)")
plt.ylabel("Water Level (metres)")
plt.title("Observed vs Predicted Water Levels in Queen Charlotte With Offset 3.9m")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# Flags (Ocean): [2]
# Flags (Load): [4]
# RMSE between observed and predicted water levels: 0.282 metres

# %%
#%%

centroid = [-132.07355559131042,
          53.24599474637989]
centroid[0] = centroid[0] + 360
date_range = [pytz.utc.localize(datetime.datetime(2014, 1, 1)), pytz.utc.localize(datetime.datetime(2024, 1, 1))]
timestep = 60 * 60  # 1 hour in seconds

dates_ts, tides_ts = SDS_slope.compute_tide(centroid, date_range, timestep, ocean_tide, load_tide)

# Adjust the predicted tide with the given offset
offset = 3.9
predicted_tides = np.array(tides_ts) + offset

dates_csv = []
observed_tides = []
with open('9850-01-JAN-2014_slev.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip header
    for row in reader:
        if len(row) >= 2:
            timestamp = datetime.datetime.strptime(row[0], '%Y-%m-%d %H:%M')
            dates_csv.append(pytz.utc.localize(timestamp))
            observed_tides.append(float(row[1]))

aligned_observed = []
aligned_predicted = []
aligned_dates = []

for date, pred_tide in zip(dates_ts, predicted_tides):
    if date in dates_csv:
        index = dates_csv.index(date)
        aligned_observed.append(observed_tides[index])
        aligned_predicted.append(pred_tide)
        aligned_dates.append(date)

# Calculate RMSE
rmse = root_mean_squared_error(aligned_observed, aligned_predicted)
print(f"RMSE between observed and predicted water levels: {rmse:.3f} metres")

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(aligned_dates, aligned_observed, label="Observed Water Level", color="blue", marker="o", linestyle="--")
plt.plot(aligned_dates, aligned_predicted, label="Predicted Water Level", color="orange", marker="x", linestyle="-")
plt.xlabel("Date and Time (UTC)")
plt.ylabel("Water Level (metres)")
plt.title("Observed vs Predicted Water Levels in Queen Charlotte With Offset 3.9m")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# Flags (Ocean): [2]
# Flags (Load): [4]
# RMSE between observed and predicted water levels: 0.275 metres

# %%
#%%

centroid = [-132.07355559131042,
          53.24599474637989]
centroid[0] = centroid[0] + 360
date_range = [pytz.utc.localize(datetime.datetime(2014, 1, 1)), pytz.utc.localize(datetime.datetime(2014, 1, 14))]
timestep = 60 * 60  # 1 hour in seconds

dates_ts, tides_ts = SDS_slope.compute_tide(centroid, date_range, timestep, ocean_tide, load_tide)

# Adjust the predicted tide with the given offset
offset = 3.9
predicted_tides = np.array(tides_ts) + offset

dates_csv = []
observed_tides = []
with open('9850-01-JAN-2014_slev.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip header
    for row in reader:
        if len(row) >= 2:
            timestamp = datetime.datetime.strptime(row[0], '%Y-%m-%d %H:%M')
            dates_csv.append(pytz.utc.localize(timestamp))
            observed_tides.append(float(row[1]))

aligned_observed = []
aligned_predicted = []
aligned_dates = []

for date, pred_tide in zip(dates_ts, predicted_tides):
    if date in dates_csv:
        index = dates_csv.index(date)
        aligned_observed.append(observed_tides[index])
        aligned_predicted.append(pred_tide)
        aligned_dates.append(date)

# Calculate RMSE
rmse = root_mean_squared_error(aligned_observed, aligned_predicted)
print(f"RMSE between observed and predicted water levels: {rmse:.3f} metres")

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(aligned_dates, aligned_observed, label="Observed Water Level", color="blue", marker="o", linestyle="--")
plt.plot(aligned_dates, aligned_predicted, label="Predicted Water Level", color="orange", marker="x", linestyle="-")
plt.xlabel("Date and Time (UTC)")
plt.ylabel("Water Level (metres)")
plt.title("Observed vs Predicted Water Levels in Queen Charlotte With Offset 3.9m")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# Flags (Ocean): [2]
# Flags (Load): [4]
# RMSE between observed and predicted water levels: 0.282 metres

# %%
#%%

centroid = [-128.03474938637248,
          50.490792629270345]
centroid[0] = centroid[0] + 360
date_range = [pytz.utc.localize(datetime.datetime(2014, 1, 1)), pytz.utc.localize(datetime.datetime(2014, 1, 14))]
timestep = 60 * 60  # 1 hour in seconds

dates_ts, tides_ts = SDS_slope.compute_tide(centroid, date_range, timestep, ocean_tide, load_tide)

# Adjust the predicted tide with the given offset
offset = 2
predicted_tides = np.array(tides_ts) + offset

dates_csv = []
observed_tides = []
with open('8735-01-JAN-2014_slev.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip header
    for row in reader:
        if len(row) >= 2:
            timestamp = datetime.datetime.strptime(row[0], '%Y-%m-%d %H:%M')
            dates_csv.append(pytz.utc.localize(timestamp))
            observed_tides.append(float(row[1]))

aligned_observed = []
aligned_predicted = []
aligned_dates = []

for date, pred_tide in zip(dates_ts, predicted_tides):
    if date in dates_csv:
        index = dates_csv.index(date)
        aligned_observed.append(observed_tides[index])
        aligned_predicted.append(pred_tide)
        aligned_dates.append(date)

# Calculate RMSE
rmse = root_mean_squared_error(aligned_observed, aligned_predicted)
print(f"RMSE between observed and predicted water levels: {rmse:.3f} metres")

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(aligned_dates, aligned_observed, label="Observed Water Level", color="blue", marker="o", linestyle="--")
plt.plot(aligned_dates, aligned_predicted, label="Predicted Water Level", color="orange", marker="x", linestyle="-")
plt.xlabel("Date and Time (UTC)")
plt.ylabel("Water Level (metres)")
plt.title("Observed vs Predicted Water Levels in Winter Harbour With Offset 2m")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# Flags (Ocean): [1]
# Flags (Load): [4]
# RMSE between observed and predicted water levels: 0.290 metres

# %%
#%%

centroid = [-128.03474938637248,
          50.490792629270345]
centroid[0] = centroid[0] + 360
date_range = [pytz.utc.localize(datetime.datetime(2014, 1, 1)), pytz.utc.localize(datetime.datetime(2024, 1, 1))]
timestep = 60 * 60  # 1 hour in seconds

dates_ts, tides_ts = SDS_slope.compute_tide(centroid, date_range, timestep, ocean_tide, load_tide)

# Adjust the predicted tide with the given offset
offset = 2
predicted_tides = np.array(tides_ts) + offset

dates_csv = []
observed_tides = []
with open('8735-01-JAN-2014_slev.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip header
    for row in reader:
        if len(row) >= 2:
            timestamp = datetime.datetime.strptime(row[0], '%Y-%m-%d %H:%M')
            dates_csv.append(pytz.utc.localize(timestamp))
            observed_tides.append(float(row[1]))

aligned_observed = []
aligned_predicted = []
aligned_dates = []

for date, pred_tide in zip(dates_ts, predicted_tides):
    if date in dates_csv:
        index = dates_csv.index(date)
        aligned_observed.append(observed_tides[index])
        aligned_predicted.append(pred_tide)
        aligned_dates.append(date)

# Calculate RMSE
rmse = root_mean_squared_error(aligned_observed, aligned_predicted)
print(f"RMSE between observed and predicted water levels: {rmse:.3f} metres")

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(aligned_dates, aligned_observed, label="Observed Water Level", color="blue", marker="o", linestyle="--")
plt.plot(aligned_dates, aligned_predicted, label="Predicted Water Level", color="orange", marker="x", linestyle="-")
plt.xlabel("Date and Time (UTC)")
plt.ylabel("Water Level (metres)")
plt.title("Observed vs Predicted Water Levels in Winter Harbour With Offset 2m")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# Flags (Ocean): [1]
# Flags (Load): [4]
# RMSE between observed and predicted water levels: 0.277 metres
